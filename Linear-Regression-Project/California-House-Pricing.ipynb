# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
#fetch dataset & separate features X and Y
#generating synthetic data for a linear regression-like problem, with some randomness

# %%
np.random.seed(42)
X = np.random.rand(50, 1) * 100
Y = 3.5 * X + np.random.randn(50, 1) * 20  #Linear relationshi + normal doitribution + moise is bigger

# %% [markdown]
# Creating and Training Linear Regression Model

# %%
model = LinearRegression()
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
#predicting Y values
Y_pred = model.predict(X)

# %%
#Regression line [V]
plt.figure(figsize=(8, 6))
plt.scatter(X, Y, color='blue', label='Data Points')
plt.plot(X, Y_pred, color='red', linewidth=2, label='Regression Line')
plt.title('Linear Regression on Random Dataset')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Slope & Intercept

# %%
print("Slope (Coefficient):", model.coef_[0][0])
print("Intercept:", model.intercept_[0])
# Out:
# Slope (Coefficient): 3.4553132007706204
# Intercept: 1.9337854893777546
